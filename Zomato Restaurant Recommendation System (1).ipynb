# %% [markdown]
# # Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Dataset

# %%
data = pd.read_csv("zomato_restaurants_in_India.csv")
data
# Out:
#           res_id                            name      establishment  \
# 0        3400299                     Bikanervala    ['Quick Bites']
# 1        3400005  Mama Chicken Mama Franky House    ['Quick Bites']
# 2        3401013                   Bhagat Halwai    ['Quick Bites']
# 3        3400290                   Bhagat Halwai    ['Quick Bites']
# 4        3401744     The Salt Cafe Kitchen & Bar  ['Casual Dining']
# ...          ...                             ...                ...
# 211939   3202251  Kali Mirch Cafe And Restaurant  ['Casual Dining']
# 211940   3200996                      Raju Omlet    ['Quick Bites']
# 211941  18984164                The Grand Thakar  ['Casual Dining']
# 211942   3201138                          Subway    ['Quick Bites']
# 211943  18879846     Freshco's - The Health Cafe           ['Café']
#
#                                                       url  \
# 0       https://www.zomato.com/agra/bikanervala-khanda...
# ...

# %% [markdown]
# # Creating another variable and uploading the same dataset
# ### Note: All the cleaning, pre-processing, analyzing part will be done in this new variable dataset

# %%
updated_data = pd.read_csv("zomato_restaurants_in_India.csv")
updated_data
# Out:
#           res_id                            name      establishment  \
# 0        3400299                     Bikanervala    ['Quick Bites']
# 1        3400005  Mama Chicken Mama Franky House    ['Quick Bites']
# 2        3401013                   Bhagat Halwai    ['Quick Bites']
# 3        3400290                   Bhagat Halwai    ['Quick Bites']
# 4        3401744     The Salt Cafe Kitchen & Bar  ['Casual Dining']
# ...          ...                             ...                ...
# 211939   3202251  Kali Mirch Cafe And Restaurant  ['Casual Dining']
# 211940   3200996                      Raju Omlet    ['Quick Bites']
# 211941  18984164                The Grand Thakar  ['Casual Dining']
# 211942   3201138                          Subway    ['Quick Bites']
# 211943  18879846     Freshco's - The Health Cafe           ['Café']
#
#                                                       url  \
# 0       https://www.zomato.com/agra/bikanervala-khanda...
# ...

# %% [markdown]
# # Getting only Mumbai city data for recommendations

# %%
updated_data = data[(data.city == 'Mumbai')]
updated_data
# Out:
#           res_id                   name      establishment  \
# 134852  18562340            Drinkery 51  ['Casual Dining']
# 134853     34757           Joey's Pizza    ['Quick Bites']
# 134854  18548172                Hitchki            ['Bar']
# 134855  18392725                Tamasha         ['Lounge']
# 134856  18962112               Bayroute    ['Fine Dining']
# ...          ...                    ...                ...
# 142348     46792       BOX8- Desi Meals                 []
# 142349     37750                 Faasos    ['Quick Bites']
# 142350  18165909  Charcoal Eats Express    ['Quick Bites']
# 142351  18306481            Wok Express     ['Food Court']
# 142352  18140577            Rasoi Thali    ['Quick Bites']
#
#                                                       url  \
# 134852  https://www.zomato.com/mumbai/drinkery-51-band...
# 134853  https://www.zomato.com/mumbai/joeys-pizza-mala...
# 134854  https://www.zomato.com/mumbai/hitchki-powai?ut...
# ...

# %%
updated_data.shape
# Out:
# (6497, 26)

# %%
updated_data.isnull().sum()
# Out:
# res_id                     0
# name                       0
# establishment              0
# url                        0
# address                    0
# city                       0
# city_id                    0
# locality                   0
# latitude                   0
# longitude                  0
# zipcode                 3109
# country_id                 0
# locality_verbose           0
# cuisines                   0
# timings                    0
# average_cost_for_two       0
# price_range                0
# currency                   0
# highlights                 0
# aggregate_rating           0
# rating_text                0
# votes                      0
# photo_count                0
# opentable_support          0
# delivery                   0
# takeaway                   0
# dtype: int64

# %% [markdown]
# ## Removing all the unnecessary cloumns and making dataset ready-to-use

# %%
updated_data = updated_data.drop(['url','price_range','locality_verbose','highlights','latitude',
                                  'longitude','zipcode','currency','photo_count',
                                  'delivery', 'takeaway','establishment','city_id','country_id',
                                  'city'], axis = 1)

# %%
updated_data.shape
# Out:
# (6497, 11)

# %%
updated_data
# Out:
#           res_id                   name  \
# 134852  18562340            Drinkery 51
# 134853     34757           Joey's Pizza
# 134854  18548172                Hitchki
# 134855  18392725                Tamasha
# 134856  18962112               Bayroute
# ...          ...                    ...
# 142348     46792       BOX8- Desi Meals
# 142349     37750                 Faasos
# 142350  18165909  Charcoal Eats Express
# 142351  18306481            Wok Express
# 142352  18140577            Rasoi Thali
#
#                                                   address  \
# 134852  1st Floor, Vibgyor Towers, Bandra Kurla Comple...
# 134853  Shop 1, Plot D, Samruddhi Complex, Chincholi B...
# 134854  5, Transocean, Hiranandani Business Park, Lake...
# 134855  Ground Floor, Victoria House, E.B Marg, Lower ...
# 134856  14, Silver Beach Estate, A.B. Nair Road, Oppos...
# ...                                                   ...
# 142348  102, Bhavani Industrial Estate, Opposite IIT B...
# ...

# %%
updated_data['name'].nunique()

# Out of 6497 rows, only 1474 are unique and recommendations will be done on these unique rows
# Out:
# 1474

# %%
updated_data.groupby('name').mean()['aggregate_rating'].sort_values(ascending = False)
# Out:
# name
# Craftbar                         4.9
# Pot Pourri                       4.9
# Palladium Social                 4.9
# Jumjoji - The Parsi Diner        4.9
# The Cheaters                     4.9
#                                 ...
# Shree Ram Lunch Home             0.0
# Shree Siddhivinayak Fast Food    0.0
# Fresh Juice Gallery              0.0
# Foodies Square                   0.0
# Mumbai 58                        0.0
# Name: aggregate_rating, Length: 1474, dtype: float64

# %%
updated_data.groupby('name').count()['votes'].sort_values(ascending = False)
# Out:
# name
# Bayroute                                       63
# Persian Darbar                                 55
# Keventers                                      53
# Hitchki                                        52
# Frozen Bottle                                  48
#                                                ..
# Farmhouse Garden Family Restaurant & Bar        1
# Piquant Biryani                                 1
# Pizza Al Passeggio-Pizza On The Go              1
# Fight For Fries                                 1
# Solitaire Restaurant - Kohinoor Continental     1
# Name: votes, Length: 1474, dtype: int64

# %%
ratings = pd.DataFrame(updated_data.groupby("name").mean()['aggregate_rating'])
ratings
# Out:
#                                aggregate_rating
# name
# 1 BHK - Brew House Kitchen                4.300
# 10th Street Cafe                          4.000
# 1441 Pizzeria                             4.300
# 145 Bandra                                4.600
# 145 Kala Ghoda                            4.600
# ...                                         ...
# Ziya - The Oberoi Mumbai                  4.300
# Zoodles - Oriental Street Wok             3.825
# Zouk                                      3.800
# Zytun - The Restaurant                    4.000
# edwins                                    3.900
#
# [1474 rows x 1 columns]

# %%
ratings['number of ratings'] = pd.DataFrame(updated_data.groupby('name').count()['votes'])
ratings
# Out:
#                                aggregate_rating  number of ratings
# name
# 1 BHK - Brew House Kitchen                4.300                 18
# 10th Street Cafe                          4.000                  3
# 1441 Pizzeria                             4.300                  4
# 145 Bandra                                4.600                 21
# 145 Kala Ghoda                            4.600                 13
# ...                                         ...                ...
# Ziya - The Oberoi Mumbai                  4.300                  6
# Zoodles - Oriental Street Wok             3.825                  8
# Zouk                                      3.800                  2
# Zytun - The Restaurant                    4.000                  1
# edwins                                    3.900                  2
#
# [1474 rows x 2 columns]

# %%
ratings.sort_values(by='aggregate_rating', ascending = False)
# Out:
#                                aggregate_rating  number of ratings
# name
# Craftbar                                    4.9                 22
# Pot Pourri                                  4.9                 21
# Palladium Social                            4.9                 21
# Jumjoji - The Parsi Diner                   4.9                  5
# The Cheaters                                4.9                  3
# ...                                         ...                ...
# Shree Ram Lunch Home                        0.0                  1
# Shree Siddhivinayak Fast Food               0.0                  1
# Fresh Juice Gallery                         0.0                  1
# Foodies Square                              0.0                  1
# Mumbai 58                                   0.0                  1
#
# [1474 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))
plt.hist(ratings['number of ratings'], bins = 70, rwidth = 0.8)
plt.show()

# %%
plt.hist(ratings['aggregate_rating'], bins = 70, rwidth = 0.8)
plt.show()

# %%
sns.jointplot(x = 'aggregate_rating', y = 'number of ratings', data = ratings, alpha = 0.5)

# %%
plt.figure(figsize = (10,6))
color = sns.color_palette('magma')
sns.heatmap(updated_data.corr(), vmax = 0.9, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Creating Recommendation System

# %%
resmatrix = updated_data.pivot_table(index = 'res_id', columns = 'name', values = 'aggregate_rating')

# %%
resmatrix
# Out:
# name      1 BHK - Brew House Kitchen  10th Street Cafe  1441 Pizzeria  \
# res_id
# 32056                            NaN               NaN            NaN
# 32081                            NaN               NaN            NaN
# 32102                            NaN               NaN            NaN
# 32109                            NaN               NaN            NaN
# 32169                            NaN               NaN            NaN
# ...                              ...               ...            ...
# 19137035                         NaN               NaN            NaN
# 19138333                         NaN               NaN            NaN
# 19138977                         NaN               NaN            NaN
# 19139840                         NaN               NaN            NaN
# 19143252                         NaN               NaN            NaN
#
# name      145 Bandra  145 Kala Ghoda  145 The Mill  180 Degrees - Radisson  \
# res_id
# ...

# %%
ratings.sort_values('number of ratings', ascending = False).head()
# Out:
#                 aggregate_rating  number of ratings
# name
# Bayroute                4.841270                 63
# Persian Darbar          4.178182                 55
# Keventers               3.781132                 53
# Hitchki                 4.728846                 52
# Frozen Bottle           3.877083                 48

# %%
df_percent = data.sample(frac=0.5)
df_percent.set_index('name', inplace=True)

# %%
indices = pd.Series(df_percent.index)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vector = TfidfVectorizer(analyzer='word', ngram_range=(1, 2), min_df=0, stop_words='english')
tfidf_matrix = tfidf_vector.fit_transform(df_percent['rating_text'])

# %%
from sklearn.metrics.pairwise import linear_kernel
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-36-7b94ea882df5> in <module>
#       1 from sklearn.metrics.pairwise import linear_kernel
# ----> 2 cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in linear_kernel(X, Y, dense_output)
#    1003     """
#    1004     X, Y = check_pairwise_arrays(X, Y)
# -> 1005     return safe_sparse_dot(X, Y.T, dense_output=dense_output)
#    1006
#    1007
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
# ...

# %%
# building the recommendation function
def recommend(name, cosine_similarities = cosine_similarities):

    # create a list to put top restaurants
    recmd_rest = []

    # find the index of the restairant entered
    idx = indices[indices == name].index[0]

    # find the restaurants with a similar cosine-sim vlaue and order them from biggest number
    score_series = pds.Series(cosine_similarities[idx]).sort_values(ascending=False)

    # extract top 30 restaurant indexes with a similar cosine-sim value
    top30 = list(score_series.iloc[0:31].index)

    # names of the top 30 restaurants
    for each in top30:
        recmd_rest.append(list(df_percent.index)[each])

    # creating the new data set to show similar restaurants
    df_new = pds.DataFrame(columns=['cuisines', 'Mean Rating', 'cost'])

    # create the top 30 similar restaurants with some of their columns
    for each in recmd_rest:
        df_new = df_new.append(pds.DataFrame(df_percent[['cuisines', 'Mean Rating', 'cost']][df_percent.index == each].sample()))

    # drop the same named restaurants with and sort only the top 10 by the highest rating
    df_new = df_new.drop_duplicates(subset=['cuisines', 'Mean Rating', 'cost'], keep=False)
    df_new = df_new.sort_values(by='Mean Rating', ascending=False).head(10)

    print('Top %s Restaurants like %s with similar reviews: ' % (str(len(df_new)), name))

    return df_new
